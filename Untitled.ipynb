# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
print(matplotlib.__version__)
# Out:
# 3.3.3

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 10, 0.1)
y = np.sin(x)

plt.figure(figsize=(10,10))
plt.plot(x, y)
plt.show()

# %%
xpoints = np.array([0, 6, 8, 9])
ypoints = np.array([0, 250, 300, 400])

plt.plot(ypoints, ls='dashed')
plt.show()

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 2, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 2, 4)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import figure
plt.figure(figsize=(1,1))
y = np.array([35, 25, 25, 15])
myexplode = [0.2, 0, 0, 0]

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-54-8ed527d88067> in <module>
#       1 import matplotlib.pyplot as plt
#       2 import numpy as np
# ----> 3 import figure
#       4 plt.figure(figsize=(1,1))
#       5 y = np.array([35, 25, 25, 15])
#
# ModuleNotFoundError: No module named 'figure'
